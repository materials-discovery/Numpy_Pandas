# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# Reading CSV file
path="/content/drive/MyDrive/Lectures_ML/Modified RAFM dataset .csv"
# Using CSV instruction to read a txt file

df = pd.read_csv(path)
# Reading Excel file
df_xls = pd.read_excel("/content/drive/MyDrive/Lectures_ML/Modified RAFM dataset.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# For csv file
print(df.head(1))

# for excel file
print(df_xls.head(3))
# Out:
#    Ref.No.     C    Cr     W    Si     V  ...    B   TT  Tt(min)     YS     US    TE
# 0        1  0.12  8.73  2.09  0.25  0.25  ...  0.0  750       60  549.0  659.0  12.3
#
# [1 rows x 15 columns]
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  ... Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0    Ref.No.          C         Cr  ...          YS          US          TE
# 1          1       0.12       8.73  ...         549         659        12.3
# 2          1        0.1       8.72  ...         544         652        12.3
#
# [3 rows x 15 columns]

# %%
#  Reading TXT file
dftxt= pd.read_csv("/content/drive/MyDrive/Lectures_ML/example_1.txt", delimiter='\t')
print(dftxt)
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
# Read columns
print(df.columns)

# Read a specific column
#df['Ref.No.']
print(df['Ref.No.'][0:5])
# or it can be printed as:
#df.Cr
# Out:
# Index(['Ref.No.', 'C', 'Cr', 'W', 'Si', 'V', 'Ta', 'Ti', 'N', 'B', 'TT',
#        'Tt(min)', 'YS', 'US', 'TE'],
#       dtype='object')
# 0    1
# 1    1
# 2    1
# 3    2
# 4    2
# Name: Ref.No., dtype: int64

# %%
# Read several columns
# print(df[['Ref.No.', 'C']])
print(df[['Ref.No.', 'C']][0:5])
# Out:
#    Ref.No.      C
# 0        1  0.120
# 1        1  0.100
# 2        1  0.092
# 3        2  0.100
# 4        2  0.100

# %%
# Read a row
print(df.iloc[0:4])
# Out:
#    Ref.No.      C    Cr     W    Si  ...   TT  Tt(min)     YS     US    TE
# 0        1  0.120  8.73  2.09  0.25  ...  750       60  549.0  659.0  12.3
# 1        1  0.100  8.72  2.09  0.23  ...  750       60  544.0  652.0  12.3
# 2        1  0.092  8.32  0.00  0.15  ...  760       60  539.0  630.0  13.3
# 3        2  0.100  9.30  0.93  0.11  ...  650      120  674.0  783.0  13.0
#
# [4 rows x 15 columns]

# %%
# Read a specific location
print(df.iloc[2,1])
# Using a loop For
# for index, row in df.iterrows():
  # print(index, row)
  # print(index, row['C'])
# Out:
# 0.092

# %%
df.loc[df['C']== 0.100]
# Out:
#     Ref.No.    C    Cr     W     Si  ...   TT  Tt(min)     YS     US    TE
# 1         1  0.1  8.72  2.09  0.230  ...  750       60  544.0  652.0  12.3
# 3         2  0.1  9.30  0.93  0.110  ...  650      120  674.0  783.0  13.0
# 4         2  0.1  9.30  0.93  0.110  ...  750      120  538.0  657.0  15.0
# 5         2  0.1  9.30  0.95  0.130  ...  650      120  573.0  698.0  16.0
# 6         2  0.1  9.30  0.95  0.130  ...  750      120  464.0  605.0  23.0
# 7         3  0.1  9.30  2.22  0.120  ...  780       90  560.0  700.0  22.0
# 10        5  0.1  8.96  1.10  0.086  ...  760       90  500.0  640.0  30.0
# 51       11  0.1  9.00  1.10  0.250  ...  750       30  652.0    NaN  20.0
# 52       11  0.1  8.60  1.30  0.100  ...  750       30  787.0    NaN  14.3
# 53       11  0.1  8.60  1.30  0.150  ...  750       30  749.0    NaN  17.1
# 59       12  0.1  8.32  1.03  0.101  ...  750       30  733.0  821.0  15.5
#
# [11 rows x 15 columns]

# %% [markdown]
# # **Sorting/Describing Data**

# %%
df.describe()
# Out:
#          Ref.No.          C         Cr  ...          YS          US         TE
# count  60.000000  60.000000  60.000000  ...   60.000000   57.000000  60.000000
# mean    6.800000   0.102883   7.696000  ...  623.300000  749.254386  14.735500
# std     3.007336   0.019715   1.749636  ...  100.609362   94.066868   6.658006
# min     1.000000   0.045000   4.610000  ...  464.000000  605.000000   6.600000
# 25%     6.000000   0.099000   6.980000  ...  544.000000  671.000000   8.425000
# 50%     6.000000   0.110000   8.600000  ...  591.000000  733.000000  13.650000
# 75%     9.000000   0.120000   8.942500  ...  715.000000  821.000000  20.275000
# max    12.000000   0.126000   9.300000  ...  824.000000  956.000000  30.000000
#
# [8 rows x 15 columns]

# %%
# Sorting values given a pre defined name in a column
#print(df.sort_values('Cr'))
# print(df.sort_values('Cr', ascending=False))
print(df.sort_values(['TT', 'W'], ascending=[1,1]))
# Out:
#     Ref.No.      C    Cr     W     Si  ...   TT  Tt(min)     YS     US     TE
# 3         2  0.100  9.30  0.93  0.110  ...  650      120  674.0  783.0  13.00
# 5         2  0.100  9.30  0.95  0.130  ...  650      120  573.0  698.0  16.00
# 29        6  0.120  7.02  1.98  0.190  ...  700       60  744.0  868.0   7.50
# 11        6  0.120  5.04  2.01  0.230  ...  700       60  714.0  823.0   8.03
# 25        6  0.120  7.01  2.01  0.190  ...  700       60  762.0  897.0   7.90
# 31        6  0.120  8.95  2.01  0.230  ...  700       60  792.0  923.0   7.60
# 33        6  0.110  8.90  2.01  0.210  ...  700       60  824.0  956.0   6.60
# 35        6  0.094  8.38  2.02  0.210  ...  700       60  810.0  938.0   7.50
# 13        6  0.110  4.67  2.11  0.200  ...  700       60  805.0  910.0   7.30
# 15        6  0.120  4.65  2.14  0.190  ...  700       60  769.0  888.0   7.50
# 21        6  0.110  4.61  2.87  0.210  ...  700       60  651.0  837.0   7.50
# 27        6  0.120  6.98  2.97  0.190  ...  700       60  780.0  912.0   8.10
# 23        6  0.110  4.61  2.99  0.210  ...  700       60  621.0  819.0   7.90
# 17        6  0.096  4.97  3.00  0.120  ...  700       60  718.0  830.0   7.60
# 19        6  0.110  4.63  3.01  0.220  ...  700       60  816.0  928.0   7.50
# 42        8  0.110  8.55  1.48  0.000  ...  740       90  563.0  671.0  22.00
# 41        8  0.120  8.50  1.50  0.000  ...  740       90  557.0  679.0  21.60
# 4         2  0.100  9.30  0.93  0.110  ...  750      120  538.0  657.0  15.00
# 6         2  0.100  9.30  0.95  0.130  ...  750      120  464.0  605.0  23.00
# 48       10  0.049  8.80  0.98  0.036  ...  750      120  592.0  695.0  19.90
# 47       10  0.049  8.82  0.99  0.038  ...  750      120  544.0  657.0  24.10
# 46       10  0.045  8.83  1.02  0.034  ...  750      120  637.0  728.0  21.10
# 59       12  0.100  8.32  1.03  0.101  ...  750       30  733.0  821.0  15.50
# 51       11  0.100  9.00  1.10  0.250  ...  750       30  652.0    NaN  20.00
# 55       12  0.110  8.94  1.20  0.109  ...  750       30  740.0  845.0  15.70
# 56       12  0.096  8.54  1.28  0.101  ...  750       30  720.0  821.0  15.00
# 57       12  0.110  8.44  1.28  0.097  ...  750       30  696.7  780.7  14.00
# 58       12  0.103  8.51  1.29  0.091  ...  750       30  673.3  760.0  14.30
# 52       11  0.100  8.60  1.30  0.100  ...  750       30  787.0    NaN  14.30
# 53       11  0.100  8.60  1.30  0.150  ...  750       30  749.0    NaN  17.10
# 49       10  0.048  8.81  1.96  0.035  ...  750      120  515.0  640.0  26.90
# 54       12  0.055  9.20  1.97  0.120  ...  750       30  514.0  629.0  28.00
# 30        6  0.120  7.02  1.98  0.190  ...  750       60  590.0  731.0   9.40
# 12        6  0.120  5.04  2.01  0.230  ...  750       60  558.0  742.0  10.00
# 26        6  0.120  7.01  2.01  0.190  ...  750       60  583.0  713.0  10.40
# 32        6  0.120  8.95  2.01  0.230  ...  750       60  596.0  737.0   9.10
# 34        6  0.110  8.90  2.01  0.210  ...  750       60  646.0  787.0   7.90
# 44        9  0.120  8.79  2.01  0.220  ...  750      120  538.0  679.0  23.00
# 36        6  0.094  8.38  2.02  0.210  ...  750       60  655.0  771.0   8.50
# 45        9  0.120  8.84  2.05  0.770  ...  750      120  561.0  730.0  23.00
# 43        9  0.110  8.86  2.07  0.050  ...  750      120  527.0  660.0  23.00
# 50       10  0.071  8.87  2.08  0.400  ...  750      120  519.0  668.8  27.90
# 0         1  0.120  8.73  2.09  0.250  ...  750       60  549.0  659.0  12.30
# 1         1  0.100  8.72  2.09  0.230  ...  750       60  544.0  652.0  12.30
# 14        6  0.110  4.67  2.11  0.200  ...  750       60  627.0  770.0   8.20
# 16        6  0.120  4.65  2.14  0.190  ...  750       60  597.0  746.0   9.30
# 22        6  0.110  4.61  2.87  0.210  ...  750       60  585.0  758.0  10.70
# 28        6  0.120  6.98  2.97  0.190  ...  750       60  597.0  756.0  11.10
# 24        6  0.110  4.61  2.99  0.210  ...  750       60  582.0  758.0  10.70
# 18        6  0.096  4.97  3.00  0.120  ...  750       60  561.0  706.0   9.50
# 20        6  0.110  4.63  3.01  0.220  ...  750       60  558.0  733.0   9.90
# 2         1  0.092  8.32  0.00  0.150  ...  760       60  539.0  630.0  13.30
# 9         4  0.110  8.70  1.00  0.000  ...  760       90  500.0  620.0  27.00
# 10        5  0.100  8.96  1.10  0.086  ...  760       90  500.0  640.0  30.00
# 37        7  0.080  9.04  1.00  0.090  ...  763       90  557.0  688.0  17.00
# 38        7  0.093  9.07  1.01  0.090  ...  763       90  492.0  650.0  17.00
# 39        7  0.126  9.03  1.39  0.060  ...  763       90  508.0  658.0  17.20
# 40        7  0.120  8.99  2.06  0.060  ...  763       90  521.0  676.0  17.40
# 7         3  0.100  9.30  2.22  0.120  ...  780       90  560.0  700.0  22.00
# 8         3  0.096  9.04  2.41  0.043  ...  780       90  520.0  690.0  22.00
#
# [60 rows x 15 columns]

# %% [markdown]
# # **Making changes to the data**

# %%
# df['Total'] = df['C'] + df['Cr']
# print(df['Total'])

# %%
df
# Out:
#     Ref.No.      C    Cr     W     Si  ...   TT  Tt(min)     YS     US     TE
# 0         1  0.120  8.73  2.09  0.250  ...  750       60  549.0  659.0  12.30
# 1         1  0.100  8.72  2.09  0.230  ...  750       60  544.0  652.0  12.30
# 2         1  0.092  8.32  0.00  0.150  ...  760       60  539.0  630.0  13.30
# 3         2  0.100  9.30  0.93  0.110  ...  650      120  674.0  783.0  13.00
# 4         2  0.100  9.30  0.93  0.110  ...  750      120  538.0  657.0  15.00
# 5         2  0.100  9.30  0.95  0.130  ...  650      120  573.0  698.0  16.00
# 6         2  0.100  9.30  0.95  0.130  ...  750      120  464.0  605.0  23.00
# 7         3  0.100  9.30  2.22  0.120  ...  780       90  560.0  700.0  22.00
# 8         3  0.096  9.04  2.41  0.043  ...  780       90  520.0  690.0  22.00
# 9         4  0.110  8.70  1.00  0.000  ...  760       90  500.0  620.0  27.00
# 10        5  0.100  8.96  1.10  0.086  ...  760       90  500.0  640.0  30.00
# 11        6  0.120  5.04  2.01  0.230  ...  700       60  714.0  823.0   8.03
# 12        6  0.120  5.04  2.01  0.230  ...  750       60  558.0  742.0  10.00
# 13        6  0.110  4.67  2.11  0.200  ...  700       60  805.0  910.0   7.30
# 14        6  0.110  4.67  2.11  0.200  ...  750       60  627.0  770.0   8.20
# 15        6  0.120  4.65  2.14  0.190  ...  700       60  769.0  888.0   7.50
# 16        6  0.120  4.65  2.14  0.190  ...  750       60  597.0  746.0   9.30
# 17        6  0.096  4.97  3.00  0.120  ...  700       60  718.0  830.0   7.60
# 18        6  0.096  4.97  3.00  0.120  ...  750       60  561.0  706.0   9.50
# 19        6  0.110  4.63  3.01  0.220  ...  700       60  816.0  928.0   7.50
# 20        6  0.110  4.63  3.01  0.220  ...  750       60  558.0  733.0   9.90
# 21        6  0.110  4.61  2.87  0.210  ...  700       60  651.0  837.0   7.50
# 22        6  0.110  4.61  2.87  0.210  ...  750       60  585.0  758.0  10.70
# 23        6  0.110  4.61  2.99  0.210  ...  700       60  621.0  819.0   7.90
# 24        6  0.110  4.61  2.99  0.210  ...  750       60  582.0  758.0  10.70
# 25        6  0.120  7.01  2.01  0.190  ...  700       60  762.0  897.0   7.90
# 26        6  0.120  7.01  2.01  0.190  ...  750       60  583.0  713.0  10.40
# 27        6  0.120  6.98  2.97  0.190  ...  700       60  780.0  912.0   8.10
# 28        6  0.120  6.98  2.97  0.190  ...  750       60  597.0  756.0  11.10
# 29        6  0.120  7.02  1.98  0.190  ...  700       60  744.0  868.0   7.50
# 30        6  0.120  7.02  1.98  0.190  ...  750       60  590.0  731.0   9.40
# 31        6  0.120  8.95  2.01  0.230  ...  700       60  792.0  923.0   7.60
# 32        6  0.120  8.95  2.01  0.230  ...  750       60  596.0  737.0   9.10
# 33        6  0.110  8.90  2.01  0.210  ...  700       60  824.0  956.0   6.60
# 34        6  0.110  8.90  2.01  0.210  ...  750       60  646.0  787.0   7.90
# 35        6  0.094  8.38  2.02  0.210  ...  700       60  810.0  938.0   7.50
# 36        6  0.094  8.38  2.02  0.210  ...  750       60  655.0  771.0   8.50
# 37        7  0.080  9.04  1.00  0.090  ...  763       90  557.0  688.0  17.00
# 38        7  0.093  9.07  1.01  0.090  ...  763       90  492.0  650.0  17.00
# 39        7  0.126  9.03  1.39  0.060  ...  763       90  508.0  658.0  17.20
# 40        7  0.120  8.99  2.06  0.060  ...  763       90  521.0  676.0  17.40
# 41        8  0.120  8.50  1.50  0.000  ...  740       90  557.0  679.0  21.60
# 42        8  0.110  8.55  1.48  0.000  ...  740       90  563.0  671.0  22.00
# 43        9  0.110  8.86  2.07  0.050  ...  750      120  527.0  660.0  23.00
# 44        9  0.120  8.79  2.01  0.220  ...  750      120  538.0  679.0  23.00
# 45        9  0.120  8.84  2.05  0.770  ...  750      120  561.0  730.0  23.00
# 46       10  0.045  8.83  1.02  0.034  ...  750      120  637.0  728.0  21.10
# 47       10  0.049  8.82  0.99  0.038  ...  750      120  544.0  657.0  24.10
# 48       10  0.049  8.80  0.98  0.036  ...  750      120  592.0  695.0  19.90
# 49       10  0.048  8.81  1.96  0.035  ...  750      120  515.0  640.0  26.90
# 50       10  0.071  8.87  2.08  0.400  ...  750      120  519.0  668.8  27.90
# 51       11  0.100  9.00  1.10  0.250  ...  750       30  652.0    NaN  20.00
# 52       11  0.100  8.60  1.30  0.100  ...  750       30  787.0    NaN  14.30
# 53       11  0.100  8.60  1.30  0.150  ...  750       30  749.0    NaN  17.10
# 54       12  0.055  9.20  1.97  0.120  ...  750       30  514.0  629.0  28.00
# 55       12  0.110  8.94  1.20  0.109  ...  750       30  740.0  845.0  15.70
# 56       12  0.096  8.54  1.28  0.101  ...  750       30  720.0  821.0  15.00
# 57       12  0.110  8.44  1.28  0.097  ...  750       30  696.7  780.7  14.00
# 58       12  0.103  8.51  1.29  0.091  ...  750       30  673.3  760.0  14.30
# 59       12  0.100  8.32  1.03  0.101  ...  750       30  733.0  821.0  15.50
#
# [60 rows x 15 columns]

# %%
# Dropping a column once has been created
# df.drop(columns=['Total'])
#   Adding predefined columns using their location
df['Total'] = df.iloc[:,0:2].sum(axis=1)

# %%
# df['Total'] # the end parameter (column) is exclusive
# df

# %% [markdown]
# # **Reordering the columns in the table**

# %%
cols = list(df.columns)
df = df[cols[0:3] + [cols[-1]] + cols[3:14]]

df.head(5)
# Out:
#    Ref.No.      C    Cr  Total     W  ...    B   TT  Tt(min)     YS     US
# 0        1  0.120  8.73  1.120  2.09  ...  0.0  750       60  549.0  659.0
# 1        1  0.100  8.72  1.100  2.09  ...  0.0  750       60  544.0  652.0
# 2        1  0.092  8.32  1.092  0.00  ...  0.0  760       60  539.0  630.0
# 3        2  0.100  9.30  2.100  0.93  ...  0.0  650      120  674.0  783.0
# 4        2  0.100  9.30  2.100  0.93  ...  0.0  750      120  538.0  657.0
#
# [5 rows x 15 columns]

# %% [markdown]
# **Creating a new file**

# %%
df.to_csv('/content/drive/MyDrive/Lectures_ML/copy_A.csv')

df.to_excel('copy1.xlsx', index = False)
# Creating a txt file
df.to_csv('modified_file.txt', index=False, sep='\t')

# %% [markdown]
# # Filtering over **data**

# %%
df.loc[df['Si'] ==0.11]
# Out:
#    Ref.No.    C   Cr  Total     W    Si  ...      N    B   TT  Tt(min)     YS     US
# 3        2  0.1  9.3    2.1  0.93  0.11  ...  0.002  0.0  650      120  674.0  783.0
# 4        2  0.1  9.3    2.1  0.93  0.11  ...  0.002  0.0  750      120  538.0  657.0
#
# [2 rows x 15 columns]

# %%
# df.loc[(df['Si'] ==0.11) & (df['N']==0.002)]
df.loc[(df['Si'] ==0.11) | (df['N']==0.002)]
# Out:
#    Ref.No.    C   Cr  Total     W    Si  ...      N    B   TT  Tt(min)     YS     US
# 3        2  0.1  9.3    2.1  0.93  0.11  ...  0.002  0.0  650      120  674.0  783.0
# 4        2  0.1  9.3    2.1  0.93  0.11  ...  0.002  0.0  750      120  538.0  657.0
# 5        2  0.1  9.3    2.1  0.95  0.13  ...  0.002  0.0  650      120  573.0  698.0
# 6        2  0.1  9.3    2.1  0.95  0.13  ...  0.002  0.0  750      120  464.0  605.0
#
# [4 rows x 15 columns]

# %%
df_xls = pd.read_excel("/content/drive/MyDrive/Lectures_ML/data_Example.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df_xls.loc[ (df_xls['Type 1'] == 'Grass') & (df_xls['Type 2'] == 'Poison') & (df_xls['HP']>70)]
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 50    45              Vileplume  Grass  ...    50           1      False
# 77    71             Victreebel  Grass  ...    70           1      False
# 652  591              Amoonguss  Grass  ...    30           5      False
#
# [5 rows x 12 columns]

# %%
new_df = df_xls.loc[ (df_xls['Type 1'] == 'Grass') & (df_xls['Type 2'] == 'Poison') & (df_xls['HP']>70)]
new_df
new_df = new_df.reset_index(drop=True)
new_df
# Out:
#      #                   Name Type 1  ... Speed  Generation  Legendary
# 0    3               Venusaur  Grass  ...    80           1      False
# 1    3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 2   45              Vileplume  Grass  ...    50           1      False
# 3   71             Victreebel  Grass  ...    70           1      False
# 4  591              Amoonguss  Grass  ...    30           5      False
#
# [5 rows x 12 columns]

# %% [markdown]
# # **Filtered by name or word**

# %%
# Columns containing a specific word
df_xls[df_xls['Name'].str.contains('Mega')]

# Columns containing not that word
#df_xls[~df_xls['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1  ... Speed  Generation  Legendary
# 3      3      VenusaurMega Venusaur     Grass  ...    80           1      False
# 7      6  CharizardMega Charizard X      Fire  ...   100           1      False
# 8      6  CharizardMega Charizard Y      Fire  ...   100           1      False
# 12     9    BlastoiseMega Blastoise     Water  ...    78           1      False
# 19    15      BeedrillMega Beedrill       Bug  ...   145           1      False
# 23    18        PidgeotMega Pidgeot    Normal  ...   121           1      False
# 71    65      AlakazamMega Alakazam   Psychic  ...   150           1      False
# 87    80        SlowbroMega Slowbro     Water  ...    30           1      False
# 102   94          GengarMega Gengar     Ghost  ...   130           1      False
# 124  115  KangaskhanMega Kangaskhan    Normal  ...   100           1      False
# 137  127          PinsirMega Pinsir       Bug  ...   105           1      False
# 141  130      GyaradosMega Gyarados     Water  ...    81           1      False
# 154  142  AerodactylMega Aerodactyl      Rock  ...   150           1      False
# 163  150        MewtwoMega Mewtwo X   Psychic  ...   130           1       True
# 164  150        MewtwoMega Mewtwo Y   Psychic  ...   140           1       True
# 168  154                   Meganium     Grass  ...    80           2      False
# 196  181      AmpharosMega Ampharos  Electric  ...    45           2      False
# 224  208        SteelixMega Steelix     Steel  ...    30           2      False
# 229  212          ScizorMega Scizor       Bug  ...    75           2      False
# 232  214    HeracrossMega Heracross       Bug  ...    75           2      False
# 248  229      HoundoomMega Houndoom      Dark  ...   115           2      False
# 268  248    TyranitarMega Tyranitar      Rock  ...    71           2      False
# 275  254      SceptileMega Sceptile     Grass  ...   145           3      False
# 279  257      BlazikenMega Blaziken      Fire  ...   100           3      False
# 283  260      SwampertMega Swampert     Water  ...    70           3      False
# 306  282    GardevoirMega Gardevoir   Psychic  ...   100           3      False
# 327  302        SableyeMega Sableye      Dark  ...    20           3      False
# 329  303          MawileMega Mawile     Steel  ...    50           3      False
# 333  306          AggronMega Aggron     Steel  ...    50           3      False
# 336  308      MedichamMega Medicham  Fighting  ...   100           3      False
# 339  310    ManectricMega Manectric  Electric  ...   135           3      False
# 349  319      SharpedoMega Sharpedo     Water  ...   105           3      False
# 354  323      CameruptMega Camerupt      Fire  ...    20           3      False
# 366  334        AltariaMega Altaria    Dragon  ...    80           3      False
# 387  354        BanetteMega Banette     Ghost  ...    75           3      False
# 393  359            AbsolMega Absol      Dark  ...   115           3      False
# 397  362          GlalieMega Glalie       Ice  ...   100           3      False
# 409  373    SalamenceMega Salamence    Dragon  ...   120           3      False
# 413  376    MetagrossMega Metagross     Steel  ...   110           3      False
# 418  380          LatiasMega Latias    Dragon  ...   110           3       True
# 420  381          LatiosMega Latios    Dragon  ...   110           3       True
# 426  384      RayquazaMega Rayquaza    Dragon  ...   115           3       True
# 476  428        LopunnyMega Lopunny    Normal  ...   135           4      False
# 494  445      GarchompMega Garchomp    Dragon  ...    92           4      False
# 498  448        LucarioMega Lucario  Fighting  ...   112           4      False
# 511  460    AbomasnowMega Abomasnow     Grass  ...    30           4      False
# 527  475        GalladeMega Gallade   Psychic  ...   110           4      False
# 591  531          AudinoMega Audino    Normal  ...    50           5      False
# 796  719        DiancieMega Diancie      Rock  ...   110           6       True
#
# [49 rows x 12 columns]

# %% [markdown]
# # **Going further!**

# %%
# We can to see 
import re # import re = regular expressions
df_xls.loc[df_xls['Type 1'].str.contains('Fire|Grass', regex=True)] # regex = regular expression 'CASE SENSITIVE'
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur  Grass  ...    45           1      False
# 1      2                Ivysaur  Grass  ...    60           1      False
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4      4             Charmander   Fire  ...    65           1      False
# ..   ...                    ...    ...  ...   ...         ...        ...
# 735  667                 Litleo   Fire  ...    72           6      False
# 736  668                 Pyroar   Fire  ...   106           6      False
# 740  672                 Skiddo  Grass  ...    52           6      False
# 741  673                 Gogoat  Grass  ...    68           6      False
# 799  721              Volcanion   Fire  ...    70           6       True
#
# [122 rows x 12 columns]

# %% [markdown]
# How to avid being CASE sensitive?

# %%
# df_xls.loc[df_xls['Type 1'].str.contains('Fire|grass', flags=re.I, regex=True)] # regex = regular expression 'CASE SENSITIVE'

# %%
# Going further
df_xls.loc[df_xls['Name'].str.contains('pi[aZ]*', flags=re.I, regex=True)] 
# pi[aZ]* means find any row that begins with pi and that contains any letter between a and z as subsequent/next letters
# Out:
#        #                     Name    Type 1  ... Speed  Generation  Legendary
# 13    10                 Caterpie       Bug  ...    45           1      False
# 20    16                   Pidgey    Normal  ...    56           1      False
# 21    17                Pidgeotto    Normal  ...    71           1      False
# 22    18                  Pidgeot    Normal  ...   101           1      False
# 23    18      PidgeotMega Pidgeot    Normal  ...   121           1      False
# 30    25                  Pikachu  Electric  ...    90           1      False
# 42    37                   Vulpix      Fire  ...    65           1      False
# 76    70               Weepinbell     Grass  ...    55           1      False
# 84    78                 Rapidash      Fire  ...   105           1      False
# 136  127                   Pinsir       Bug  ...    85           1      False
# 137  127        PinsirMega Pinsir       Bug  ...   105           1      False
# 181  167                 Spinarak       Bug  ...    30           2      False
# 186  172                    Pichu  Electric  ...    60           2      False
# 189  175                   Togepi     Fairy  ...    20           2      False
# 202  187                   Hoppip     Grass  ...    50           2      False
# 219  204                   Pineco       Bug  ...    15           2      False
# 239  221                Piloswine       Ice  ...    50           2      False
# 266  247                  Pupitar      Rock  ...    51           2      False
# 345  316                   Gulpin    Poison  ...    40           3      False
# 357  326                  Grumpig   Psychic  ...    80           3      False
# 358  327                   Spinda    Normal  ...    60           3      False
# 359  328                 Trapinch    Ground  ...    10           3      False
# 390  357                  Tropius     Grass  ...    51           3      False
# 438  393                   Piplup     Water  ...    40           4      False
# 463  416                Vespiquen       Bug  ...    40           4      False
# 488  440                  Happiny    Normal  ...    30           4      False
# 490  442                Spiritomb     Ghost  ...    35           4      False
# 501  451                  Skorupi    Poison  ...    65           4      False
# 502  452                  Drapion    Poison  ...    95           4      False
# 557  498                    Tepig      Fire  ...    45           5      False
# 558  499                  Pignite      Fire  ...    55           5      False
# 578  519                   Pidove    Normal  ...    43           5      False
# 596  536                Palpitoad     Water  ...    69           5      False
# 716  648  MeloettaPirouette Forme    Normal  ...   128           5      False
# 718  650                  Chespin     Grass  ...    38           6      False
#
# [35 rows x 12 columns]

# %%
# Going further
df_xls.loc[df_xls['Name'].str.contains('^pi[aZ]*', flags=re.I, regex=True)] # to indicate to look for those names that only start with pi include ^
# pi[aZ]* means find any row that begins with pi and that contains any letter between a and z as subsequent/next letters
# Out:
#        #                 Name    Type 1  ... Speed  Generation  Legendary
# 20    16               Pidgey    Normal  ...    56           1      False
# 21    17            Pidgeotto    Normal  ...    71           1      False
# 22    18              Pidgeot    Normal  ...   101           1      False
# 23    18  PidgeotMega Pidgeot    Normal  ...   121           1      False
# 30    25              Pikachu  Electric  ...    90           1      False
# 136  127               Pinsir       Bug  ...    85           1      False
# 137  127    PinsirMega Pinsir       Bug  ...   105           1      False
# 186  172                Pichu  Electric  ...    60           2      False
# 219  204               Pineco       Bug  ...    15           2      False
# 239  221            Piloswine       Ice  ...    50           2      False
# 438  393               Piplup     Water  ...    40           4      False
# 558  499              Pignite      Fire  ...    55           5      False
# 578  519               Pidove    Normal  ...    43           5      False
#
# [13 rows x 12 columns]

# %% [markdown]
# # **Conditional Changes**

# %%
df_xls.loc[df_xls['Type 2'] == 'Poison', 'Legendary'] = True 
# Change all elements in column 'Legendary' to true with the name Poison in column 2

df_xls
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1       True
# 1      2                Ivysaur    Grass  ...    60           1       True
# 2      3               Venusaur    Grass  ...    80           1       True
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1       True
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# # **What about conditional change using more than two columns?**

# %%
# Lets read again the file since we have messed it up
df_xls = pd.read_excel("/content/drive/MyDrive/Lectures_ML/data_Example.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df_xls.loc[df_xls['Speed'] > 70, ['Generation','Legendary']] = ['Change 1','Change 2']
df_xls
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80    Change 1   Change 2
# 3      3  VenusaurMega Venusaur    Grass  ...    80    Change 1   Change 2
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110    Change 1   Change 2
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80    Change 1   Change 2
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# # **Aggregate some Statistics**

# %%
# Lets read again the file since we have messed it up
df_xls = pd.read_excel("/content/drive/MyDrive/Lectures_ML/data_Example.xlsx")
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df_xls.groupby(['Type 1']).mean()
# Out:
#                    #         HP      Attack  ...       Speed  Generation  Legendary
# Type 1                                       ...
# Bug       334.492754  56.884058   70.971014  ...   61.681159    3.217391   0.000000
# Dark      461.354839  66.806452   88.387097  ...   76.161290    4.032258   0.064516
# Dragon    474.375000  83.312500  112.125000  ...   83.031250    3.875000   0.375000
# Electric  363.500000  59.795455   69.090909  ...   84.500000    3.272727   0.090909
# Fairy     449.529412  74.117647   61.529412  ...   48.588235    4.117647   0.058824
# Fighting  363.851852  69.851852   96.777778  ...   66.074074    3.370370   0.000000
# Fire      327.403846  69.903846   84.769231  ...   74.442308    3.211538   0.096154
# Flying    677.750000  70.750000   78.750000  ...  102.500000    5.500000   0.500000
# Ghost     486.500000  64.437500   73.781250  ...   64.343750    4.187500   0.062500
# Grass     344.871429  67.271429   73.214286  ...   61.928571    3.357143   0.042857
# Ground    356.281250  73.781250   95.750000  ...   63.906250    3.156250   0.125000
# Ice       423.541667  72.000000   72.750000  ...   63.458333    3.541667   0.083333
# Normal    319.173469  77.275510   73.469388  ...   71.551020    3.051020   0.020408
# Poison    251.785714  67.250000   74.678571  ...   63.571429    2.535714   0.000000
# Psychic   380.807018  70.631579   71.456140  ...   81.491228    3.385965   0.245614
# Rock      392.727273  65.363636   92.863636  ...   55.909091    3.454545   0.090909
# Steel     442.851852  65.222222   92.703704  ...   55.259259    3.851852   0.148148
# Water     303.089286  72.062500   74.151786  ...   65.964286    2.857143   0.035714
#
# [18 rows x 9 columns]

# %%
df_xls.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                    #         HP      Attack  ...       Speed  Generation  Legendary
# Type 1                                       ...
# Steel     442.851852  65.222222   92.703704  ...   55.259259    3.851852   0.148148
# Rock      392.727273  65.363636   92.863636  ...   55.909091    3.454545   0.090909
# Dragon    474.375000  83.312500  112.125000  ...   83.031250    3.875000   0.375000
# Ground    356.281250  73.781250   95.750000  ...   63.906250    3.156250   0.125000
# Ghost     486.500000  64.437500   73.781250  ...   64.343750    4.187500   0.062500
# Water     303.089286  72.062500   74.151786  ...   65.964286    2.857143   0.035714
# Ice       423.541667  72.000000   72.750000  ...   63.458333    3.541667   0.083333
# Grass     344.871429  67.271429   73.214286  ...   61.928571    3.357143   0.042857
# Bug       334.492754  56.884058   70.971014  ...   61.681159    3.217391   0.000000
# Dark      461.354839  66.806452   88.387097  ...   76.161290    4.032258   0.064516
# Poison    251.785714  67.250000   74.678571  ...   63.571429    2.535714   0.000000
# Fire      327.403846  69.903846   84.769231  ...   74.442308    3.211538   0.096154
# Psychic   380.807018  70.631579   71.456140  ...   81.491228    3.385965   0.245614
# Electric  363.500000  59.795455   69.090909  ...   84.500000    3.272727   0.090909
# Flying    677.750000  70.750000   78.750000  ...  102.500000    5.500000   0.500000
# Fighting  363.851852  69.851852   96.777778  ...   66.074074    3.370370   0.000000
# Fairy     449.529412  74.117647   61.529412  ...   48.588235    4.117647   0.058824
# Normal    319.173469  77.275510   73.469388  ...   71.551020    3.051020   0.020408
#
# [18 rows x 9 columns]

# %%
# df_xls.groupby(['Type 1']).sum()
# df_xls.groupby(['Type 1']).count()
df_xls['count'] = 1
df_xls
# Just to show the column with the count
df_xls.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
# Multiple parameters
df_xls.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
#Working with large amounts of Data
#  Panda allows you to work with big data
df_xls.to_csv('/content/drive/MyDrive/Lectures_ML/modified.csv')
for df_1 in pd.read_csv('/content/drive/MyDrive/Lectures_ML/modified.csv', chunksize=5):
  print("Chunk size")
  print(df_1)
# Out:
# Chunk size
#    Unnamed: 0  #                   Name  ... Generation Legendary  count
# 0           0  1              Bulbasaur  ...          1     False      1
# 1           1  2                Ivysaur  ...          1     False      1
# 2           2  3               Venusaur  ...          1     False      1
# 3           3  3  VenusaurMega Venusaur  ...          1     False      1
# 4           4  4             Charmander  ...          1     False      1
#
# [5 rows x 14 columns]
# Chunk size
#    Unnamed: 0  #                       Name  ... Generation Legendary  count
# 5           5  5                 Charmeleon  ...          1     False      1
# 6           6  6                  Charizard  ...          1     False      1
# 7           7  6  CharizardMega Charizard X  ...          1     False      1
# 8           8  6  CharizardMega Charizard Y  ...          1     False      1
# 9           9  7                   Squirtle  ...          1     False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #                     Name  ... Generation  Legendary  count
# 10          10   8                Wartortle  ...          1      False      1
# 11          11   9                Blastoise  ...          1      False      1
# 12          12   9  BlastoiseMega Blastoise  ...          1      False      1
# 13          13  10                 Caterpie  ...          1      False      1
# 14          14  11                  Metapod  ...          1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #                   Name  ... Generation Legendary  count
# 15          15  12             Butterfree  ...          1     False      1
# 16          16  13                 Weedle  ...          1     False      1
# 17          17  14                 Kakuna  ...          1     False      1
# 18          18  15               Beedrill  ...          1     False      1
# 19          19  15  BeedrillMega Beedrill  ...          1     False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #                 Name  ... Generation Legendary  count
# 20          20  16               Pidgey  ...          1     False      1
# 21          21  17            Pidgeotto  ...          1     False      1
# 22          22  18              Pidgeot  ...          1     False      1
# 23          23  18  PidgeotMega Pidgeot  ...          1     False      1
# 24          24  19              Rattata  ...          1     False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #      Name  Type 1  ... Speed  Generation  Legendary  count
# 25          25  20  Raticate  Normal  ...    97           1      False      1
# 26          26  21   Spearow  Normal  ...    70           1      False      1
# 27          27  22    Fearow  Normal  ...   100           1      False      1
# 28          28  23     Ekans  Poison  ...    55           1      False      1
# 29          29  24     Arbok  Poison  ...    80           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #              Name  ... Generation  Legendary  count
# 30          30  25           Pikachu  ...          1      False      1
# 31          31  26            Raichu  ...          1      False      1
# 32          32  27         Sandshrew  ...          1      False      1
# 33          33  28         Sandslash  ...          1      False      1
# 34          34  29  Nidoran (Female)  ...          1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #            Name  Type 1  ... Speed  Generation  Legendary  count
# 35          35  30        Nidorina  Poison  ...    56           1      False      1
# 36          36  31       Nidoqueen  Poison  ...    76           1      False      1
# 37          37  32  Nidoran (Male)  Poison  ...    50           1      False      1
# 38          38  33        Nidorino  Poison  ...    65           1      False      1
# 39          39  34        Nidoking  Poison  ...    85           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #        Name  Type 1  ... Speed  Generation  Legendary  count
# 40          40  35    Clefairy   Fairy  ...    35           1      False      1
# 41          41  36    Clefable   Fairy  ...    60           1      False      1
# 42          42  37      Vulpix    Fire  ...    65           1      False      1
# 43          43  38   Ninetales    Fire  ...   100           1      False      1
# 44          44  39  Jigglypuff  Normal  ...    20           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #        Name  Type 1  ... Speed  Generation  Legendary  count
# 45          45  40  Wigglytuff  Normal  ...    45           1      False      1
# 46          46  41       Zubat  Poison  ...    55           1      False      1
# 47          47  42      Golbat  Poison  ...    90           1      False      1
# 48          48  43      Oddish   Grass  ...    30           1      False      1
# 49          49  44       Gloom   Grass  ...    40           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #       Name Type 1  ... Speed  Generation  Legendary  count
# 50          50  45  Vileplume  Grass  ...    50           1      False      1
# 51          51  46      Paras    Bug  ...    25           1      False      1
# 52          52  47   Parasect    Bug  ...    30           1      False      1
# 53          53  48    Venonat    Bug  ...    45           1      False      1
# 54          54  49   Venomoth    Bug  ...    90           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #     Name  Type 1  ...  Speed  Generation  Legendary  count
# 55          55  50  Diglett  Ground  ...     95           1      False      1
# 56          56  51  Dugtrio  Ground  ...    120           1      False      1
# 57          57  52   Meowth  Normal  ...     90           1      False      1
# 58          58  53  Persian  Normal  ...    115           1      False      1
# 59          59  54  Psyduck   Water  ...     55           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #       Name    Type 1  ...  Speed  Generation  Legendary  count
# 60          60  55    Golduck     Water  ...     85           1      False      1
# 61          61  56     Mankey  Fighting  ...     70           1      False      1
# 62          62  57   Primeape  Fighting  ...     95           1      False      1
# 63          63  58  Growlithe      Fire  ...     60           1      False      1
# 64          64  59   Arcanine      Fire  ...     95           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #       Name   Type 1  ... Speed  Generation  Legendary  count
# 65          65  60    Poliwag    Water  ...    90           1      False      1
# 66          66  61  Poliwhirl    Water  ...    90           1      False      1
# 67          67  62  Poliwrath    Water  ...    70           1      False      1
# 68          68  63       Abra  Psychic  ...    90           1      False      1
# 69          69  64    Kadabra  Psychic  ...   105           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #                   Name  ... Generation  Legendary  count
# 70          70  65               Alakazam  ...          1      False      1
# 71          71  65  AlakazamMega Alakazam  ...          1      False      1
# 72          72  66                 Machop  ...          1      False      1
# 73          73  67                Machoke  ...          1      False      1
# 74          74  68                Machamp  ...          1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #        Name Type 1  ... Speed  Generation  Legendary  count
# 75          75  69  Bellsprout  Grass  ...    40           1      False      1
# 76          76  70  Weepinbell  Grass  ...    55           1      False      1
# 77          77  71  Victreebel  Grass  ...    70           1      False      1
# 78          78  72   Tentacool  Water  ...    70           1      False      1
# 79          79  73  Tentacruel  Water  ...   100           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #      Name Type 1  ... Speed  Generation  Legendary  count
# 80          80  74   Geodude   Rock  ...    20           1      False      1
# 81          81  75  Graveler   Rock  ...    35           1      False      1
# 82          82  76     Golem   Rock  ...    45           1      False      1
# 83          83  77    Ponyta   Fire  ...    90           1      False      1
# 84          84  78  Rapidash   Fire  ...   105           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #                 Name  ... Generation Legendary  count
# 85          85  79             Slowpoke  ...          1     False      1
# 86          86  80              Slowbro  ...          1     False      1
# 87          87  80  SlowbroMega Slowbro  ...          1     False      1
# 88          88  81            Magnemite  ...          1     False      1
# 89          89  82             Magneton  ...          1     False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #        Name  Type 1  ... Speed  Generation  Legendary  count
# 90          90  83  Farfetch'd  Normal  ...    60           1      False      1
# 91          91  84       Doduo  Normal  ...    75           1      False      1
# 92          92  85      Dodrio  Normal  ...   100           1      False      1
# 93          93  86        Seel   Water  ...    45           1      False      1
# 94          94  87     Dewgong   Water  ...    70           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#     Unnamed: 0   #      Name  Type 1  ... Speed  Generation  Legendary  count
# 95          95  88    Grimer  Poison  ...    25           1      False      1
# 96          96  89       Muk  Poison  ...    50           1      False      1
# 97          97  90  Shellder   Water  ...    40           1      False      1
# 98          98  91  Cloyster   Water  ...    70           1      False      1
# 99          99  92    Gastly   Ghost  ...    80           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0   #               Name  ... Generation Legendary  count
# 100         100  93            Haunter  ...          1     False      1
# 101         101  94             Gengar  ...          1     False      1
# 102         102  94  GengarMega Gengar  ...          1     False      1
# 103         103  95               Onix  ...          1     False      1
# 104         104  96            Drowzee  ...          1     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name    Type 1  ...  Speed  Generation  Legendary  count
# 105         105   97      Hypno   Psychic  ...     67           1      False      1
# 106         106   98     Krabby     Water  ...     50           1      False      1
# 107         107   99    Kingler     Water  ...     75           1      False      1
# 108         108  100    Voltorb  Electric  ...    100           1      False      1
# 109         109  101  Electrode  Electric  ...    140           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name    Type 1  ... Speed  Generation  Legendary  count
# 110         110  102  Exeggcute     Grass  ...    40           1      False      1
# 111         111  103  Exeggutor     Grass  ...    55           1      False      1
# 112         112  104     Cubone    Ground  ...    35           1      False      1
# 113         113  105    Marowak    Ground  ...    45           1      False      1
# 114         114  106  Hitmonlee  Fighting  ...    87           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name    Type 1  ... Speed  Generation  Legendary  count
# 115         115  107  Hitmonchan  Fighting  ...    76           1      False      1
# 116         116  108   Lickitung    Normal  ...    30           1      False      1
# 117         117  109     Koffing    Poison  ...    35           1      False      1
# 118         118  110     Weezing    Poison  ...    60           1      False      1
# 119         119  111     Rhyhorn    Ground  ...    25           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                       Name  ... Generation Legendary  count
# 120         120  112                     Rhydon  ...          1     False      1
# 121         121  113                    Chansey  ...          1     False      1
# 122         122  114                    Tangela  ...          1     False      1
# 123         123  115                 Kangaskhan  ...          1     False      1
# 124         124  115  KangaskhanMega Kangaskhan  ...          1     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #     Name Type 1  ...  Speed  Generation  Legendary  count
# 125         125  116   Horsea  Water  ...     60           1      False      1
# 126         126  117   Seadra  Water  ...     85           1      False      1
# 127         127  118  Goldeen  Water  ...     63           1      False      1
# 128         128  119  Seaking  Water  ...     68           1      False      1
# 129         129  120   Staryu  Water  ...     85           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name    Type 1  ... Speed  Generation  Legendary  count
# 130         130  121     Starmie     Water  ...   115           1      False      1
# 131         131  122    Mr. Mime   Psychic  ...    90           1      False      1
# 132         132  123     Scyther       Bug  ...   105           1      False      1
# 133         133  124        Jynx       Ice  ...    95           1      False      1
# 134         134  125  Electabuzz  Electric  ...   105           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #               Name  ... Generation Legendary  count
# 135         135  126             Magmar  ...          1     False      1
# 136         136  127             Pinsir  ...          1     False      1
# 137         137  127  PinsirMega Pinsir  ...          1     False      1
# 138         138  128             Tauros  ...          1     False      1
# 139         139  129           Magikarp  ...          1     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 140         140  130               Gyarados  ...          1     False      1
# 141         141  130  GyaradosMega Gyarados  ...          1     False      1
# 142         142  131                 Lapras  ...          1     False      1
# 143         143  132                  Ditto  ...          1     False      1
# 144         144  133                  Eevee  ...          1     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name    Type 1  ... Speed  Generation  Legendary  count
# 145         145  134  Vaporeon     Water  ...    65           1      False      1
# 146         146  135   Jolteon  Electric  ...   130           1      False      1
# 147         147  136   Flareon      Fire  ...    65           1      False      1
# 148         148  137   Porygon    Normal  ...    40           1      False      1
# 149         149  138   Omanyte      Rock  ...    35           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                       Name  ... Generation Legendary  count
# 150         150  139                    Omastar  ...          1     False      1
# 151         151  140                     Kabuto  ...          1     False      1
# 152         152  141                   Kabutops  ...          1     False      1
# 153         153  142                 Aerodactyl  ...          1     False      1
# 154         154  142  AerodactylMega Aerodactyl  ...          1     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name    Type 1  ... Speed  Generation  Legendary  count
# 155         155  143   Snorlax    Normal  ...    30           1      False      1
# 156         156  144  Articuno       Ice  ...    85           1       True      1
# 157         157  145    Zapdos  Electric  ...   100           1       True      1
# 158         158  146   Moltres      Fire  ...    90           1       True      1
# 159         159  147   Dratini    Dragon  ...    50           1      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                 Name  ... Generation Legendary  count
# 160         160  148            Dragonair  ...          1     False      1
# 161         161  149            Dragonite  ...          1     False      1
# 162         162  150               Mewtwo  ...          1      True      1
# 163         163  150  MewtwoMega Mewtwo X  ...          1      True      1
# 164         164  150  MewtwoMega Mewtwo Y  ...          1      True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name   Type 1  ...  Speed  Generation  Legendary  count
# 165         165  151        Mew  Psychic  ...    100           1      False      1
# 166         166  152  Chikorita    Grass  ...     45           2      False      1
# 167         167  153    Bayleef    Grass  ...     60           2      False      1
# 168         168  154   Meganium    Grass  ...     80           2      False      1
# 169         169  155  Cyndaquil     Fire  ...     65           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name Type 1  ...  Speed  Generation  Legendary  count
# 170         170  156     Quilava   Fire  ...     80           2      False      1
# 171         171  157  Typhlosion   Fire  ...    100           2      False      1
# 172         172  158    Totodile  Water  ...     43           2      False      1
# 173         173  159    Croconaw  Water  ...     58           2      False      1
# 174         174  160  Feraligatr  Water  ...     78           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name  Type 1  ... Speed  Generation  Legendary  count
# 175         175  161   Sentret  Normal  ...    20           2      False      1
# 176         176  162    Furret  Normal  ...    90           2      False      1
# 177         177  163  Hoothoot  Normal  ...    50           2      False      1
# 178         178  164   Noctowl  Normal  ...    70           2      False      1
# 179         179  165    Ledyba     Bug  ...    55           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name  Type 1  ... Speed  Generation  Legendary  count
# 180         180  166    Ledian     Bug  ...    85           2      False      1
# 181         181  167  Spinarak     Bug  ...    30           2      False      1
# 182         182  168   Ariados     Bug  ...    40           2      False      1
# 183         183  169    Crobat  Poison  ...   130           2      False      1
# 184         184  170  Chinchou   Water  ...    67           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name    Type 1  ... Speed  Generation  Legendary  count
# 185         185  171    Lanturn     Water  ...    67           2      False      1
# 186         186  172      Pichu  Electric  ...    60           2      False      1
# 187         187  173     Cleffa     Fairy  ...    15           2      False      1
# 188         188  174  Igglybuff    Normal  ...    15           2      False      1
# 189         189  175     Togepi     Fairy  ...    20           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #     Name    Type 1  ... Speed  Generation  Legendary  count
# 190         190  176  Togetic     Fairy  ...    40           2      False      1
# 191         191  177     Natu   Psychic  ...    70           2      False      1
# 192         192  178     Xatu   Psychic  ...    95           2      False      1
# 193         193  179   Mareep  Electric  ...    35           2      False      1
# 194         194  180  Flaaffy  Electric  ...    45           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 195         195  181               Ampharos  ...          2     False      1
# 196         196  181  AmpharosMega Ampharos  ...          2     False      1
# 197         197  182              Bellossom  ...          2     False      1
# 198         198  183                 Marill  ...          2     False      1
# 199         199  184              Azumarill  ...          2     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name Type 1  ... Speed  Generation  Legendary  count
# 200         200  185  Sudowoodo   Rock  ...    30           2      False      1
# 201         201  186   Politoed  Water  ...    70           2      False      1
# 202         202  187     Hoppip  Grass  ...    50           2      False      1
# 203         203  188   Skiploom  Grass  ...    80           2      False      1
# 204         204  189   Jumpluff  Grass  ...   110           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name  Type 1  ... Speed  Generation  Legendary  count
# 205         205  190     Aipom  Normal  ...    85           2      False      1
# 206         206  191   Sunkern   Grass  ...    30           2      False      1
# 207         207  192  Sunflora   Grass  ...    30           2      False      1
# 208         208  193     Yanma     Bug  ...    95           2      False      1
# 209         209  194    Wooper   Water  ...    15           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name   Type 1  ... Speed  Generation  Legendary  count
# 210         210  195  Quagsire    Water  ...    35           2      False      1
# 211         211  196    Espeon  Psychic  ...   110           2      False      1
# 212         212  197   Umbreon     Dark  ...    65           2      False      1
# 213         213  198   Murkrow     Dark  ...    91           2      False      1
# 214         214  199  Slowking    Water  ...    30           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name   Type 1  ... Speed  Generation  Legendary  count
# 215         215  200  Misdreavus    Ghost  ...    85           2      False      1
# 216         216  201       Unown  Psychic  ...    48           2      False      1
# 217         217  202   Wobbuffet  Psychic  ...    33           2      False      1
# 218         218  203   Girafarig   Normal  ...    85           2      False      1
# 219         219  204      Pineco      Bug  ...    15           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                 Name  ... Generation Legendary  count
# 220         220  205           Forretress  ...          2     False      1
# 221         221  206            Dunsparce  ...          2     False      1
# 222         222  207               Gligar  ...          2     False      1
# 223         223  208              Steelix  ...          2     False      1
# 224         224  208  SteelixMega Steelix  ...          2     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #               Name  ... Generation Legendary  count
# 225         225  209           Snubbull  ...          2     False      1
# 226         226  210           Granbull  ...          2     False      1
# 227         227  211           Qwilfish  ...          2     False      1
# 228         228  212             Scizor  ...          2     False      1
# 229         229  212  ScizorMega Scizor  ...          2     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                     Name  ... Generation Legendary  count
# 230         230  213                  Shuckle  ...          2     False      1
# 231         231  214                Heracross  ...          2     False      1
# 232         232  214  HeracrossMega Heracross  ...          2     False      1
# 233         233  215                  Sneasel  ...          2     False      1
# 234         234  216                Teddiursa  ...          2     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name  Type 1  ... Speed  Generation  Legendary  count
# 235         235  217   Ursaring  Normal  ...    55           2      False      1
# 236         236  218     Slugma    Fire  ...    20           2      False      1
# 237         237  219   Magcargo    Fire  ...    30           2      False      1
# 238         238  220     Swinub     Ice  ...    50           2      False      1
# 239         239  221  Piloswine     Ice  ...    50           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name Type 1  ... Speed  Generation  Legendary  count
# 240         240  222    Corsola  Water  ...    35           2      False      1
# 241         241  223   Remoraid  Water  ...    65           2      False      1
# 242         242  224  Octillery  Water  ...    45           2      False      1
# 243         243  225   Delibird    Ice  ...    75           2      False      1
# 244         244  226    Mantine  Water  ...    70           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 245         245  227               Skarmory  ...          2     False      1
# 246         246  228               Houndour  ...          2     False      1
# 247         247  229               Houndoom  ...          2     False      1
# 248         248  229  HoundoomMega Houndoom  ...          2     False      1
# 249         249  230                Kingdra  ...          2     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name  Type 1  ...  Speed  Generation  Legendary  count
# 250         250  231    Phanpy  Ground  ...     40           2      False      1
# 251         251  232   Donphan  Ground  ...     50           2      False      1
# 252         252  233  Porygon2  Normal  ...     60           2      False      1
# 253         253  234  Stantler  Normal  ...     85           2      False      1
# 254         254  235  Smeargle  Normal  ...     75           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name    Type 1  ... Speed  Generation  Legendary  count
# 255         255  236    Tyrogue  Fighting  ...    35           2      False      1
# 256         256  237  Hitmontop  Fighting  ...    70           2      False      1
# 257         257  238   Smoochum       Ice  ...    65           2      False      1
# 258         258  239     Elekid  Electric  ...    95           2      False      1
# 259         259  240      Magby      Fire  ...    83           2      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #     Name    Type 1  ...  Speed  Generation  Legendary  count
# 260         260  241  Miltank    Normal  ...    100           2      False      1
# 261         261  242  Blissey    Normal  ...     55           2      False      1
# 262         262  243   Raikou  Electric  ...    115           2       True      1
# 263         263  244    Entei      Fire  ...    100           2       True      1
# 264         264  245  Suicune     Water  ...     85           2       True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                     Name  ... Generation Legendary  count
# 265         265  246                 Larvitar  ...          2     False      1
# 266         266  247                  Pupitar  ...          2     False      1
# 267         267  248                Tyranitar  ...          2     False      1
# 268         268  248  TyranitarMega Tyranitar  ...          2     False      1
# 269         269  249                    Lugia  ...          2      True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name   Type 1  ... Speed  Generation  Legendary  count
# 270         270  250     Ho-oh     Fire  ...    90           2       True      1
# 271         271  251    Celebi  Psychic  ...   100           2      False      1
# 272         272  252   Treecko    Grass  ...    70           3      False      1
# 273         273  253   Grovyle    Grass  ...    95           3      False      1
# 274         274  254  Sceptile    Grass  ...   120           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 275         275  254  SceptileMega Sceptile  ...          3     False      1
# 276         276  255                Torchic  ...          3     False      1
# 277         277  256              Combusken  ...          3     False      1
# 278         278  257               Blaziken  ...          3     False      1
# 279         279  257  BlazikenMega Blaziken  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 280         280  258                 Mudkip  ...          3     False      1
# 281         281  259              Marshtomp  ...          3     False      1
# 282         282  260               Swampert  ...          3     False      1
# 283         283  260  SwampertMega Swampert  ...          3     False      1
# 284         284  261              Poochyena  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name  Type 1  ...  Speed  Generation  Legendary  count
# 285         285  262  Mightyena    Dark  ...     70           3      False      1
# 286         286  263  Zigzagoon  Normal  ...     60           3      False      1
# 287         287  264    Linoone  Normal  ...    100           3      False      1
# 288         288  265    Wurmple     Bug  ...     20           3      False      1
# 289         289  266    Silcoon     Bug  ...     15           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name Type 1  ... Speed  Generation  Legendary  count
# 290         290  267  Beautifly    Bug  ...    65           3      False      1
# 291         291  268    Cascoon    Bug  ...    15           3      False      1
# 292         292  269     Dustox    Bug  ...    65           3      False      1
# 293         293  270      Lotad  Water  ...    30           3      False      1
# 294         294  271     Lombre  Water  ...    50           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name  Type 1  ... Speed  Generation  Legendary  count
# 295         295  272  Ludicolo   Water  ...    70           3      False      1
# 296         296  273    Seedot   Grass  ...    30           3      False      1
# 297         297  274   Nuzleaf   Grass  ...    60           3      False      1
# 298         298  275   Shiftry   Grass  ...    80           3      False      1
# 299         299  276   Taillow  Normal  ...    85           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name   Type 1  ... Speed  Generation  Legendary  count
# 300         300  277   Swellow   Normal  ...   125           3      False      1
# 301         301  278   Wingull    Water  ...    85           3      False      1
# 302         302  279  Pelipper    Water  ...    65           3      False      1
# 303         303  280     Ralts  Psychic  ...    40           3      False      1
# 304         304  281    Kirlia  Psychic  ...    50           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                     Name  ... Generation Legendary  count
# 305         305  282                Gardevoir  ...          3     False      1
# 306         306  282  GardevoirMega Gardevoir  ...          3     False      1
# 307         307  283                  Surskit  ...          3     False      1
# 308         308  284               Masquerain  ...          3     False      1
# 309         309  285                Shroomish  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name  Type 1  ... Speed  Generation  Legendary  count
# 310         310  286   Breloom   Grass  ...    70           3      False      1
# 311         311  287   Slakoth  Normal  ...    30           3      False      1
# 312         312  288  Vigoroth  Normal  ...    90           3      False      1
# 313         313  289   Slaking  Normal  ...   100           3      False      1
# 314         314  290   Nincada     Bug  ...    40           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name  Type 1  ... Speed  Generation  Legendary  count
# 315         315  291   Ninjask     Bug  ...   160           3      False      1
# 316         316  292  Shedinja     Bug  ...    40           3      False      1
# 317         317  293   Whismur  Normal  ...    28           3      False      1
# 318         318  294   Loudred  Normal  ...    48           3      False      1
# 319         319  295   Exploud  Normal  ...    68           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name    Type 1  ... Speed  Generation  Legendary  count
# 320         320  296  Makuhita  Fighting  ...    25           3      False      1
# 321         321  297  Hariyama  Fighting  ...    50           3      False      1
# 322         322  298   Azurill    Normal  ...    20           3      False      1
# 323         323  299  Nosepass      Rock  ...    30           3      False      1
# 324         324  300    Skitty    Normal  ...    50           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                 Name  ... Generation Legendary  count
# 325         325  301             Delcatty  ...          3     False      1
# 326         326  302              Sableye  ...          3     False      1
# 327         327  302  SableyeMega Sableye  ...          3     False      1
# 328         328  303               Mawile  ...          3     False      1
# 329         329  303    MawileMega Mawile  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #               Name  ... Generation Legendary  count
# 330         330  304               Aron  ...          3     False      1
# 331         331  305             Lairon  ...          3     False      1
# 332         332  306             Aggron  ...          3     False      1
# 333         333  306  AggronMega Aggron  ...          3     False      1
# 334         334  307           Meditite  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                     Name  ... Generation Legendary  count
# 335         335  308                 Medicham  ...          3     False      1
# 336         336  308    MedichamMega Medicham  ...          3     False      1
# 337         337  309                Electrike  ...          3     False      1
# 338         338  310                Manectric  ...          3     False      1
# 339         339  310  ManectricMega Manectric  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name    Type 1  ... Speed  Generation  Legendary  count
# 340         340  311    Plusle  Electric  ...    95           3      False      1
# 341         341  312     Minun  Electric  ...    95           3      False      1
# 342         342  313   Volbeat       Bug  ...    85           3      False      1
# 343         343  314  Illumise       Bug  ...    85           3      False      1
# 344         344  315   Roselia     Grass  ...    65           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 345         345  316                 Gulpin  ...          3     False      1
# 346         346  317                 Swalot  ...          3     False      1
# 347         347  318               Carvanha  ...          3     False      1
# 348         348  319               Sharpedo  ...          3     False      1
# 349         349  319  SharpedoMega Sharpedo  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 350         350  320                Wailmer  ...          3     False      1
# 351         351  321                Wailord  ...          3     False      1
# 352         352  322                  Numel  ...          3     False      1
# 353         353  323               Camerupt  ...          3     False      1
# 354         354  323  CameruptMega Camerupt  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name   Type 1  ...  Speed  Generation  Legendary  count
# 355         355  324   Torkoal     Fire  ...     20           3      False      1
# 356         356  325    Spoink  Psychic  ...     60           3      False      1
# 357         357  326   Grumpig  Psychic  ...     80           3      False      1
# 358         358  327    Spinda   Normal  ...     60           3      False      1
# 359         359  328  Trapinch   Ground  ...     10           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name  Type 1  ... Speed  Generation  Legendary  count
# 360         360  329   Vibrava  Ground  ...    70           3      False      1
# 361         361  330    Flygon  Ground  ...   100           3      False      1
# 362         362  331    Cacnea   Grass  ...    35           3      False      1
# 363         363  332  Cacturne   Grass  ...    55           3      False      1
# 364         364  333    Swablu  Normal  ...    50           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                 Name  ... Generation Legendary  count
# 365         365  334              Altaria  ...          3     False      1
# 366         366  334  AltariaMega Altaria  ...          3     False      1
# 367         367  335             Zangoose  ...          3     False      1
# 368         368  336              Seviper  ...          3     False      1
# 369         369  337             Lunatone  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name Type 1  ... Speed  Generation  Legendary  count
# 370         370  338    Solrock   Rock  ...    70           3      False      1
# 371         371  339   Barboach  Water  ...    60           3      False      1
# 372         372  340   Whiscash  Water  ...    60           3      False      1
# 373         373  341   Corphish  Water  ...    35           3      False      1
# 374         374  342  Crawdaunt  Water  ...    55           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #     Name  Type 1  ... Speed  Generation  Legendary  count
# 375         375  343   Baltoy  Ground  ...    55           3      False      1
# 376         376  344  Claydol  Ground  ...    75           3      False      1
# 377         377  345   Lileep    Rock  ...    23           3      False      1
# 378         378  346  Cradily    Rock  ...    43           3      False      1
# 379         379  347  Anorith    Rock  ...    75           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name  Type 1  ... Speed  Generation  Legendary  count
# 380         380  348   Armaldo    Rock  ...    45           3      False      1
# 381         381  349    Feebas   Water  ...    80           3      False      1
# 382         382  350   Milotic   Water  ...    81           3      False      1
# 383         383  351  Castform  Normal  ...    70           3      False      1
# 384         384  352   Kecleon  Normal  ...    40           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                 Name  ... Generation  Legendary  count
# 385         385  353              Shuppet  ...          3      False      1
# 386         386  354              Banette  ...          3      False      1
# 387         387  354  BanetteMega Banette  ...          3      False      1
# 388         388  355              Duskull  ...          3      False      1
# 389         389  356             Dusclops  ...          3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #             Name  ... Generation Legendary  count
# 390         390  357          Tropius  ...          3     False      1
# 391         391  358         Chimecho  ...          3     False      1
# 392         392  359            Absol  ...          3     False      1
# 393         393  359  AbsolMega Absol  ...          3     False      1
# 394         394  360           Wynaut  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #               Name  ... Generation Legendary  count
# 395         395  361            Snorunt  ...          3     False      1
# 396         396  362             Glalie  ...          3     False      1
# 397         397  362  GlalieMega Glalie  ...          3     False      1
# 398         398  363             Spheal  ...          3     False      1
# 399         399  364             Sealeo  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name Type 1  ... Speed  Generation  Legendary  count
# 400         400  365    Walrein    Ice  ...    65           3      False      1
# 401         401  366   Clamperl  Water  ...    32           3      False      1
# 402         402  367    Huntail  Water  ...    52           3      False      1
# 403         403  368   Gorebyss  Water  ...    52           3      False      1
# 404         404  369  Relicanth  Water  ...    55           3      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                     Name  ... Generation Legendary  count
# 405         405  370                  Luvdisc  ...          3     False      1
# 406         406  371                    Bagon  ...          3     False      1
# 407         407  372                  Shelgon  ...          3     False      1
# 408         408  373                Salamence  ...          3     False      1
# 409         409  373  SalamenceMega Salamence  ...          3     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                     Name  ... Generation Legendary  count
# 410         410  374                   Beldum  ...          3     False      1
# 411         411  375                   Metang  ...          3     False      1
# 412         412  376                Metagross  ...          3     False      1
# 413         413  376  MetagrossMega Metagross  ...          3     False      1
# 414         414  377                 Regirock  ...          3      True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #               Name  ... Generation Legendary  count
# 415         415  378             Regice  ...          3      True      1
# 416         416  379          Registeel  ...          3      True      1
# 417         417  380             Latias  ...          3      True      1
# 418         418  380  LatiasMega Latias  ...          3      True      1
# 419         419  381             Latios  ...          3      True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 420         420  381      LatiosMega Latios  ...          3      True      1
# 421         421  382                 Kyogre  ...          3      True      1
# 422         422  382    KyogrePrimal Kyogre  ...          3      True      1
# 423         423  383                Groudon  ...          3      True      1
# 424         424  383  GroudonPrimal Groudon  ...          3      True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 425         425  384               Rayquaza  ...          3      True      1
# 426         426  384  RayquazaMega Rayquaza  ...          3      True      1
# 427         427  385                Jirachi  ...          3      True      1
# 428         428  386     DeoxysNormal Forme  ...          3      True      1
# 429         429  386     DeoxysAttack Forme  ...          3      True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                 Name  ... Generation Legendary  count
# 430         430  386  DeoxysDefense Forme  ...          3      True      1
# 431         431  386    DeoxysSpeed Forme  ...          3      True      1
# 432         432  387              Turtwig  ...          4     False      1
# 433         433  388               Grotle  ...          4     False      1
# 434         434  389             Torterra  ...          4     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name Type 1  ... Speed  Generation  Legendary  count
# 435         435  390   Chimchar   Fire  ...    61           4      False      1
# 436         436  391   Monferno   Fire  ...    81           4      False      1
# 437         437  392  Infernape   Fire  ...   108           4      False      1
# 438         438  393     Piplup  Water  ...    40           4      False      1
# 439         439  394   Prinplup  Water  ...    50           4      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name  Type 1  ... Speed  Generation  Legendary  count
# 440         440  395   Empoleon   Water  ...    60           4      False      1
# 441         441  396     Starly  Normal  ...    60           4      False      1
# 442         442  397   Staravia  Normal  ...    80           4      False      1
# 443         443  398  Staraptor  Normal  ...   100           4      False      1
# 444         444  399     Bidoof  Normal  ...    31           4      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name    Type 1  ... Speed  Generation  Legendary  count
# 445         445  400     Bibarel    Normal  ...    71           4      False      1
# 446         446  401   Kricketot       Bug  ...    25           4      False      1
# 447         447  402  Kricketune       Bug  ...    65           4      False      1
# 448         448  403       Shinx  Electric  ...    45           4      False      1
# 449         449  404       Luxio  Electric  ...    60           4      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name    Type 1  ... Speed  Generation  Legendary  count
# 450         450  405     Luxray  Electric  ...    70           4      False      1
# 451         451  406      Budew     Grass  ...    55           4      False      1
# 452         452  407   Roserade     Grass  ...    90           4      False      1
# 453         453  408   Cranidos      Rock  ...    58           4      False      1
# 454         454  409  Rampardos      Rock  ...    58           4      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                 Name  ... Generation Legendary  count
# 455         455  410             Shieldon  ...          4     False      1
# 456         456  411            Bastiodon  ...          4     False      1
# 457         457  412                Burmy  ...          4     False      1
# 458         458  413  WormadamPlant Cloak  ...          4     False      1
# 459         459  413  WormadamSandy Cloak  ...          4     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                 Name  ... Generation Legendary  count
# 460         460  413  WormadamTrash Cloak  ...          4     False      1
# 461         461  414               Mothim  ...          4     False      1
# 462         462  415               Combee  ...          4     False      1
# 463         463  416            Vespiquen  ...          4     False      1
# 464         464  417            Pachirisu  ...          4     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name Type 1  ...  Speed  Generation  Legendary  count
# 465         465  418    Buizel  Water  ...     85           4      False      1
# 466         466  419  Floatzel  Water  ...    115           4      False      1
# 467         467  420   Cherubi  Grass  ...     35           4      False      1
# 468         468  421   Cherrim  Grass  ...     85           4      False      1
# 469         469  422   Shellos  Water  ...     34           4      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name  Type 1  ... Speed  Generation  Legendary  count
# 470         470  423  Gastrodon   Water  ...    39           4      False      1
# 471         471  424    Ambipom  Normal  ...   115           4      False      1
# 472         472  425   Drifloon   Ghost  ...    70           4      False      1
# ...
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name    Type 1  ... Speed  Generation  Legendary  count
# 645         645  584   Vanilluxe       Ice  ...    79           5      False      1
# 646         646  585    Deerling    Normal  ...    75           5      False      1
# 647         647  586    Sawsbuck    Normal  ...    95           5      False      1
# 648         648  587      Emolga  Electric  ...   103           5      False      1
# 649         649  588  Karrablast       Bug  ...    60           5      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name Type 1  ... Speed  Generation  Legendary  count
# 650         650  589  Escavalier    Bug  ...    20           5      False      1
# 651         651  590     Foongus  Grass  ...    15           5      False      1
# 652         652  591   Amoonguss  Grass  ...    30           5      False      1
# 653         653  592    Frillish  Water  ...    40           5      False      1
# 654         654  593   Jellicent  Water  ...    60           5      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name Type 1  ... Speed  Generation  Legendary  count
# 655         655  594   Alomomola  Water  ...    65           5      False      1
# 656         656  595      Joltik    Bug  ...    65           5      False      1
# 657         657  596  Galvantula    Bug  ...   108           5      False      1
# 658         658  597   Ferroseed  Grass  ...    10           5      False      1
# 659         659  598  Ferrothorn  Grass  ...    20           5      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name    Type 1  ...  Speed  Generation  Legendary  count
# 660         660  599      Klink     Steel  ...     30           5      False      1
# 661         661  600      Klang     Steel  ...     50           5      False      1
# 662         662  601  Klinklang     Steel  ...     90           5      False      1
# 663         663  602     Tynamo  Electric  ...     60           5      False      1
# 664         664  603  Eelektrik  Electric  ...     40           5      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name    Type 1  ... Speed  Generation  Legendary  count
# 665         665  604  Eelektross  Electric  ...    50           5      False      1
# 666         666  605      Elgyem   Psychic  ...    30           5      False      1
# 667         667  606    Beheeyem   Psychic  ...    40           5      False      1
# 668         668  607     Litwick     Ghost  ...    20           5      False      1
# 669         669  608     Lampent     Ghost  ...    55           5      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name  Type 1  ... Speed  Generation  Legendary  count
# 670         670  609  Chandelure   Ghost  ...    80           5      False      1
# 671         671  610        Axew  Dragon  ...    57           5      False      1
# 672         672  611     Fraxure  Dragon  ...    67           5      False      1
# 673         673  612     Haxorus  Dragon  ...    97           5      False      1
# 674         674  613     Cubchoo     Ice  ...    40           5      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name  Type 1  ... Speed  Generation  Legendary  count
# 675         675  614    Beartic     Ice  ...    50           5      False      1
# 676         676  615  Cryogonal     Ice  ...   105           5      False      1
# 677         677  616    Shelmet     Bug  ...    25           5      False      1
# 678         678  617   Accelgor     Bug  ...   145           5      False      1
# 679         679  618   Stunfisk  Ground  ...    32           5      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name    Type 1  ... Speed  Generation  Legendary  count
# 680         680  619    Mienfoo  Fighting  ...    65           5      False      1
# 681         681  620   Mienshao  Fighting  ...   105           5      False      1
# 682         682  621  Druddigon    Dragon  ...    48           5      False      1
# 683         683  622     Golett    Ground  ...    35           5      False      1
# 684         684  623     Golurk    Ground  ...    55           5      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name  Type 1  ... Speed  Generation  Legendary  count
# 685         685  624    Pawniard    Dark  ...    60           5      False      1
# 686         686  625     Bisharp    Dark  ...    70           5      False      1
# 687         687  626  Bouffalant  Normal  ...    55           5      False      1
# 688         688  627     Rufflet  Normal  ...    60           5      False      1
# 689         689  628    Braviary  Normal  ...    80           5      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name Type 1  ... Speed  Generation  Legendary  count
# 690         690  629    Vullaby   Dark  ...    60           5      False      1
# 691         691  630  Mandibuzz   Dark  ...    80           5      False      1
# 692         692  631    Heatmor   Fire  ...    65           5      False      1
# 693         693  632     Durant    Bug  ...   109           5      False      1
# 694         694  633      Deino   Dark  ...    38           5      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name Type 1  ... Speed  Generation  Legendary  count
# 695         695  634   Zweilous   Dark  ...    58           5      False      1
# 696         696  635  Hydreigon   Dark  ...    98           5      False      1
# 697         697  636   Larvesta    Bug  ...    60           5      False      1
# 698         698  637  Volcarona    Bug  ...   100           5      False      1
# 699         699  638   Cobalion  Steel  ...   108           5       True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                      Name  ... Generation Legendary  count
# 700         700  639                 Terrakion  ...          5      True      1
# 701         701  640                  Virizion  ...          5      True      1
# 702         702  641   TornadusIncarnate Forme  ...          5      True      1
# 703         703  641     TornadusTherian Forme  ...          5      True      1
# 704         704  642  ThundurusIncarnate Forme  ...          5      True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                     Name  ... Generation Legendary  count
# 705         705  642   ThundurusTherian Forme  ...          5      True      1
# 706         706  643                 Reshiram  ...          5      True      1
# 707         707  644                   Zekrom  ...          5      True      1
# 708         708  645  LandorusIncarnate Forme  ...          5      True      1
# 709         709  645    LandorusTherian Forme  ...          5      True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                  Name  ... Generation Legendary  count
# 710         710  646                Kyurem  ...          5      True      1
# 711         711  646    KyuremBlack Kyurem  ...          5      True      1
# 712         712  646    KyuremWhite Kyurem  ...          5      True      1
# 713         713  647  KeldeoOrdinary Forme  ...          5     False      1
# 714         714  647  KeldeoResolute Forme  ...          5     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                     Name  ... Generation Legendary  count
# 715         715  648       MeloettaAria Forme  ...          5     False      1
# 716         716  648  MeloettaPirouette Forme  ...          5     False      1
# 717         717  649                 Genesect  ...          5     False      1
# 718         718  650                  Chespin  ...          6     False      1
# 719         719  651                Quilladin  ...          6     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name Type 1  ... Speed  Generation  Legendary  count
# 720         720  652  Chesnaught  Grass  ...    64           6      False      1
# 721         721  653    Fennekin   Fire  ...    60           6      False      1
# 722         722  654     Braixen   Fire  ...    73           6      False      1
# 723         723  655     Delphox   Fire  ...   104           6      False      1
# 724         724  656     Froakie  Water  ...    71           6      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name  Type 1  ... Speed  Generation  Legendary  count
# 725         725  657   Frogadier   Water  ...    97           6      False      1
# 726         726  658    Greninja   Water  ...   122           6      False      1
# 727         727  659    Bunnelby  Normal  ...    57           6      False      1
# 728         728  660   Diggersby  Normal  ...    78           6      False      1
# 729         729  661  Fletchling  Normal  ...    62           6      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #         Name Type 1  ... Speed  Generation  Legendary  count
# 730         730  662  Fletchinder   Fire  ...    84           6      False      1
# 731         731  663   Talonflame   Fire  ...   126           6      False      1
# 732         732  664   Scatterbug    Bug  ...    35           6      False      1
# 733         733  665       Spewpa    Bug  ...    29           6      False      1
# 734         734  666     Vivillon    Bug  ...    89           6      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name Type 1  ... Speed  Generation  Legendary  count
# 735         735  667     Litleo   Fire  ...    72           6      False      1
# 736         736  668     Pyroar   Fire  ...   106           6      False      1
# 737         737  669  Flab̩b̩  Fairy  ...    42           6      False      1
# 738         738  670    Floette  Fairy  ...    52           6      False      1
# 739         739  671    Florges  Fairy  ...    75           6      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #     Name    Type 1  ... Speed  Generation  Legendary  count
# 740         740  672   Skiddo     Grass  ...    52           6      False      1
# 741         741  673   Gogoat     Grass  ...    68           6      False      1
# 742         742  674  Pancham  Fighting  ...    43           6      False      1
# 743         743  675  Pangoro  Fighting  ...    58           6      False      1
# 744         744  676  Furfrou    Normal  ...   102           6      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #            Name  ... Generation Legendary  count
# 745         745  677          Espurr  ...          6     False      1
# 746         746  678    MeowsticMale  ...          6     False      1
# 747         747  678  MeowsticFemale  ...          6     False      1
# 748         748  679         Honedge  ...          6     False      1
# 749         749  680        Doublade  ...          6     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 750         750  681   AegislashBlade Forme  ...          6     False      1
# 751         751  681  AegislashShield Forme  ...          6     False      1
# 752         752  682               Spritzee  ...          6     False      1
# 753         753  683             Aromatisse  ...          6     False      1
# 754         754  684                Swirlix  ...          6     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name Type 1  ... Speed  Generation  Legendary  count
# 755         755  685    Slurpuff  Fairy  ...    72           6      False      1
# 756         756  686       Inkay   Dark  ...    45           6      False      1
# 757         757  687     Malamar   Dark  ...    73           6      False      1
# 758         758  688     Binacle   Rock  ...    50           6      False      1
# 759         759  689  Barbaracle   Rock  ...    68           6      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #        Name    Type 1  ... Speed  Generation  Legendary  count
# 760         760  690      Skrelp    Poison  ...    30           6      False      1
# 761         761  691    Dragalge    Poison  ...    44           6      False      1
# 762         762  692   Clauncher     Water  ...    44           6      False      1
# 763         763  693   Clawitzer     Water  ...    59           6      False      1
# 764         764  694  Helioptile  Electric  ...    70           6      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name    Type 1  ... Speed  Generation  Legendary  count
# 765         765  695  Heliolisk  Electric  ...   109           6      False      1
# 766         766  696     Tyrunt      Rock  ...    48           6      False      1
# 767         767  697  Tyrantrum      Rock  ...    71           6      False      1
# 768         768  698     Amaura      Rock  ...    46           6      False      1
# 769         769  699    Aurorus      Rock  ...    58           6      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #      Name    Type 1  ... Speed  Generation  Legendary  count
# 770         770  700   Sylveon     Fairy  ...    60           6      False      1
# 771         771  701  Hawlucha  Fighting  ...   118           6      False      1
# 772         772  702   Dedenne  Electric  ...   101           6      False      1
# 773         773  703   Carbink      Rock  ...    50           6      False      1
# 774         774  704     Goomy    Dragon  ...    40           6      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #       Name  Type 1  ... Speed  Generation  Legendary  count
# 775         775  705    Sliggoo  Dragon  ...    60           6      False      1
# 776         776  706     Goodra  Dragon  ...    80           6      False      1
# 777         777  707     Klefki   Steel  ...    75           6      False      1
# 778         778  708   Phantump   Ghost  ...    38           6      False      1
# 779         779  709  Trevenant   Ghost  ...    56           6      False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 780         780  710  PumpkabooAverage Size  ...          6     False      1
# 781         781  710    PumpkabooSmall Size  ...          6     False      1
# 782         782  710    PumpkabooLarge Size  ...          6     False      1
# 783         783  710    PumpkabooSuper Size  ...          6     False      1
# 784         784  711  GourgeistAverage Size  ...          6     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                 Name  ... Generation Legendary  count
# 785         785  711  GourgeistSmall Size  ...          6     False      1
# 786         786  711  GourgeistLarge Size  ...          6     False      1
# 787         787  711  GourgeistSuper Size  ...          6     False      1
# 788         788  712             Bergmite  ...          6     False      1
# 789         789  713              Avalugg  ...          6     False      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #              Name  ... Generation Legendary  count
# 790         790  714            Noibat  ...          6     False      1
# 791         791  715           Noivern  ...          6     False      1
# 792         792  716           Xerneas  ...          6      True      1
# 793         793  717           Yveltal  ...          6      True      1
# 794         794  718  Zygarde50% Forme  ...          6      True      1
#
# [5 rows x 14 columns]
# Chunk size
#      Unnamed: 0    #                 Name  ... Generation Legendary  count
# 795         795  719              Diancie  ...          6      True      1
# 796         796  719  DiancieMega Diancie  ...          6      True      1
# 797         797  720  HoopaHoopa Confined  ...          6      True      1
# 798         798  720   HoopaHoopa Unbound  ...          6      True      1
# 799         799  721            Volcanion  ...          6      True      1
#
# [5 rows x 14 columns]

# %%
new_df = pd.DataFrame(columns=df.columns)
for df_1 in pd.read_csv('/content/drive/MyDrive/Lectures_ML/modified.csv', chunksize=5):
  results = df_1.groupby(['Type 1']).count()

  new_df = pd.concat([new_df, results])
new_df
# Out:
#         Ref.No.    C   Cr Total  ... Speed Generation Legendary count
# Fire        NaN  NaN  NaN   NaN  ...   1.0        1.0       1.0   1.0
# Grass       NaN  NaN  NaN   NaN  ...   4.0        4.0       4.0   4.0
# Fire        NaN  NaN  NaN   NaN  ...   4.0        4.0       4.0   4.0
# Water       NaN  NaN  NaN   NaN  ...   1.0        1.0       1.0   1.0
# Bug         NaN  NaN  NaN   NaN  ...   2.0        2.0       2.0   2.0
# ...         ...  ...  ...   ...  ...   ...        ...       ...   ...
# Fairy       NaN  NaN  NaN   NaN  ...   1.0        1.0       1.0   1.0
# Flying      NaN  NaN  NaN   NaN  ...   2.0        2.0       2.0   2.0
# Fire        NaN  NaN  NaN   NaN  ...   1.0        1.0       1.0   1.0
# Psychic     NaN  NaN  NaN   NaN  ...   2.0        2.0       2.0   2.0
# Rock        NaN  NaN  NaN   NaN  ...   2.0        2.0       2.0   2.0
#
# [433 rows x 28 columns]
